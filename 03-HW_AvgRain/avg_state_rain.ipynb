# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,5))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x11993c5f8>,
#   <matplotlib.axis.XTick at 0x11658c4a8>,
#   <matplotlib.axis.XTick at 0x1053c7198>,
#   <matplotlib.axis.XTick at 0x117af0860>,
#   <matplotlib.axis.XTick at 0x117af0cf8>,
#   <matplotlib.axis.XTick at 0x117af0908>,
#   <matplotlib.axis.XTick at 0x117af8438>,
#   <matplotlib.axis.XTick at 0x117af8908>,
#   <matplotlib.axis.XTick at 0x117af8dd8>,
#   <matplotlib.axis.XTick at 0x117b032e8>,
#   <matplotlib.axis.XTick at 0x117b037b8>,
#   <matplotlib.axis.XTick at 0x117b03c88>,
#   <matplotlib.axis.XTick at 0x117b09198>,
#   <matplotlib.axis.XTick at 0x117b09668>,
#   <matplotlib.axis.XTick at 0x117b09b38>,
#   <matplotlib.axis.XTick at 0x117b09be0>,
#   <matplotlib.axis.XTick at 0x117b03be0>,
#   <matplotlib.axis.XTick at 0x117af8c50>,
#   <matplotlib.axis.XTick at 0x117b0e2e8>,
#   <matplotlib.axis.XTick at 0x117b0e7b8>,
#   <matplotlib.axis.XTick at 0x117b0ec88>,
#   <matplotlib.axis.XTick at 0x117b1a198>,
#   <matplotlib.axis.XTick at 0x117b1a668>,
#   <matplotlib.axis.XTick at 0x117b1ab38>,
#   <matplotlib.axis.XTick at 0x117b210b8>,
#   <matplotlib.axis.XTick at 0x117b1a748>,
#   <matplotlib.axis.XTick at 0x117b0e908>,
#   <matplotlib.axis.XTick at 0x117b03fd0>,
#   <matplotlib.axis.XTick at 0x117b21828>,
#   <matplotlib.axis.XTick at 0x117b21da0>,
#   <matplotlib.axis.XTick at 0x117b2b358>,
#   <matplotlib.axis.XTick at 0x117b2b8d0>,
#   <matplotlib.axis.XTick at 0x117b2be48>,
#   <matplotlib.axis.XTick at 0x117b2e400>,
#   <matplotlib.axis.XTick at 0x117b2e978>,
#   <matplotlib.axis.XTick at 0x117b2b828>,
#   <matplotlib.axis.XTick at 0x117b0e898>,
#   <matplotlib.axis.XTick at 0x117b2ee10>,
#   <matplotlib.axis.XTick at 0x117b3a3c8>,
#   <matplotlib.axis.XTick at 0x117b3a940>,
#   <matplotlib.axis.XTick at 0x117b3aeb8>,
#   <matplotlib.axis.XTick at 0x117b40470>,
#   <matplotlib.axis.XTick at 0x117b409e8>,
#   <matplotlib.axis.XTick at 0x117b40f60>,
#   <matplotlib.axis.XTick at 0x117b403c8>,
#   <matplotlib.axis.XTick at 0x117b3a7b8>,
#   <matplotlib.axis.XTick at 0x117b21470>,
#   <matplotlib.axis.XTick at 0x117b480f0>,
#   <matplotlib.axis.XTick at 0x117b48b38>,
#   <matplotlib.axis.XTick at 0x117b4e160>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Avg. Rain/State")
plt.xlabel("State")
plt.ylabel("Avg. Rainfall")
# Out:
# Text(433.94444444444446, 0.5, 'Avg. Rainfall')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("avg state rain.png")
plt.show()
